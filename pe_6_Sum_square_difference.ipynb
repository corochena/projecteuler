# %% [markdown]
# <a href="https://colab.research.google.com/github/corochena/projecteuler/blob/main/pe_6_Sum_square_difference.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import numpy as np

def dif(): 
  x = np.arange(101)
  xsq = x*x
  sumsq = sum(x)**2
  print(sumsq - sum(xsq))

dif()
# Out:
# 25164150
