# %% [markdown]
# <a href="https://colab.research.google.com/github/corochena/projecteuler/blob/main/pe_47_Distinct_primes_factors.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
def primesOrig(n):
  primes = [2]

  for num in range(primes[-1] + 1, n + 1):
    isPrime = True
    for div in primes:
      if num % div == 0:
        isPrime = False
        break
      if div > num**0.5:
        break
    if isPrime:
      primes.append(num)

  return primes

def primeDivisors(n):
  divisors = set()
  for p in primesList:
    if p > n:
      break
    if n % p == 0:
      divisors.add(p)
      n = n/p
  return divisors

# %%
primesList = primesOrig(1000000)

# %%
start = 645

while True:
  divlist = []
  for i in range(4):
    divisors = primeDivisors(start + i)
    if len(divisors) == 4:
      divlist.append(divisors)
    else:
      break
  if len(divlist) == 4:
    d1, d2, d3, d4 = divlist
    if d1 & d2 & d3 & d4 == set():
      break
  start += 1
  
  if start >= 200000:
    break

print(start)
# Out:
# 134043

# %%
print(primeDivisors(134043))
print(primeDivisors(134044))
print(primeDivisors(134045))
# Out:
# {3, 491, 13, 7}
# {2, 31, 47, 23}
# {17, 83, 19, 5}

# %%
print(primeDivisors(645))
print(primeDivisors(646))
print(primeDivisors(647))
# Out:
# {43, 3, 5}
# {17, 2, 19}
# {647}

# %%
set1 = {1,3,4}
set2 = {5,7}
(set1 & set2) == set()
# Out:
# True
