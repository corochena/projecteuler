# %% [markdown]
# <a href="https://colab.research.google.com/github/corochena/projecteuler/blob/main/pe_9_Special_Pythagorean_triplet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
def findPit():
  for a in range(1,1000):
    for b in range(1, 1000):
      c = 1000 - a - b
      if a**2 + b**2 == c**2:
        print(a, b, c)
        print(a*b*c)
        return

findPit()
# Out:
# 200 375 425
# 31875000
