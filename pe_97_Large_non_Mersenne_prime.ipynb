# %% [markdown]
# <a href="https://colab.research.google.com/github/corochena/projecteuler/blob/main/pe_97_Large_non_Mersenne_prime.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# problema 97: Large non-Mersenne prime

p = 7830457
c = 28433
n = c*2**p + 1
r = n % int(1e10)
print(r)
# Out:
# 8739992577
