# %% [markdown]
# <a href="https://colab.research.google.com/github/corochena/projecteuler/blob/main/pe_8_Largest_product_in_a_series.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
def prob8():
  bignum = ...

  bigstr = str(bignum)
  gtprod = 1
  adj = ""
  n = 13

  def prodOfDig(string):
    p = 1
    for num in string:
      p *= int(num)
    return p

  for i in range(len(bigstr) - n):
    seqnum = bigstr[i:i+n]
    temp = prodOfDig(seqnum)
    if temp > gtprod:
      gtprod = temp
      adj = seqnum
      
  print(gtprod, adj)

prob8()
# Out:
# 23514624000 5576689664895
